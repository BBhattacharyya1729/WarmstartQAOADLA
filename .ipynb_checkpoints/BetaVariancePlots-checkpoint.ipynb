# %%
from QAOAUtils import * 
from LieUtils import *

# %%
with open('beta_variance_runs.pkl', 'rb') as f:
    all_runs = pickle.load(f)

# %%
all_variance_plot_together("", all_runs, initial_p=10, max_p=210, step_size=10)

# %%
all_variance_plot_separate("", all_runs)

# %%
Default_Larger = new_lst(all_runs, [0, 2, 5, 6])
Default_Smaller = new_lst(all_runs, [1, 3, 4, 7, 8, 9])
Default_Equal = new_lst(all_runs, [10])

# %%
GW_angles_2d(Default_Larger, "GW Angles in 2D for Default Larger Variance")

# %%
GW_angles_2d(Default_Smaller, "GW Angles in 2D for Default Smaller Variance")

# %%
GW_angles_2d(Default_Equal, "GW Angles in 2D for Default Equal Variance")

# %%
GW_angles_3d(Default_Larger, "GW Angles in 3D for Default Greater Variance")

# %%
GW_angles_3d(Default_Smaller, "GW Angles in 3D for Default Smaller Variance")

# %%
GW_angles_3d(Default_Equal, "GW Angles in 3D for Default Equal Variance")

# %%
gw_angles_graph(Default_Larger, "GW Angles Graph for Default Larger Variance")

# %%
gw_angles_graph(Default_Smaller, "GW Angles Graph for Default Smaller Variance")

# %%
gw_angles_graph(Default_Equal, "GW Angles Graph for Default Equal Variance")

# %%
coplanar_runs(Default_Smaller, "Coplanar points for Default Smaller") #Numeric, tolerance of 1e-2
# Out:
# Coplanar points for Default Smaller
# YES
# YES
# YES
# YES
# YES
# YES

# %%
coplanar_runs(Default_Larger, "Coplanar points for Default Larger")
# Out:
# Coplanar points for Default Larger
# NO
# YES
# YES
# NO

# %%
coplanar_runs(Default_Equal, "Coplanar points for Default Equal")
# Out:
# Coplanar points for Default Equal
# YES
